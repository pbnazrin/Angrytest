# %% [markdown]
# <a href="https://colab.research.google.com/github/pbnazrin/Angrytest/blob/master/unet_tf_grad_cam_correct.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://github.com/linhaoqi027/SEG-GRAD-CAM

# %% [markdown]
# https://github.com/kiraving/SegGradCAM

# %% [markdown]
# https://github.com/chungtd89/unet/blob/master/model.py

# %% [markdown]
# https://github.com/chungtd89/grad-cam-heat-map-membrane-segmentation-u-net/blob/master/src/Membrane_Segmentation_Heatmap_GradCAM_stepperepoch100.ipynb

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import sys
ROOT_DIR="/content/drive/MyDrive/Mtech_project/Nazrin_F4K_segmentation_Model1/Unet_segmentation"
sys.path.append(ROOT_DIR)

# %%
import os
import numpy as np
import cv2
from glob import glob
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, CSVLogger, TensorBoard
import matplotlib.pyplot as plt
#from data import load_data, tf_dataset
from data import load_data
from model_py import build_model

#from grad_cam1 import GradCam1,superimpose
from grad_cam2 import GradCam,GradCam1,superimpose,GradCamPlusPlus, ScoreCam, build_guided_model, GuidedBackPropagation, superimpose
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
model=build_model()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/layers/normalization/batch_normalization.py:532: _colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 96, 96, 3)]  0           []
#
#  conv2d (Conv2D)                (None, 96, 96, 16)   448         ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 96, 96, 16)  64          ['conv2d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 96, 96, 16)   0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 96, 96, 16)   2320        ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 96, 96, 16)  64          ['conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 96, 96, 16)   0           ['batch_normalization_1[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 48, 48, 16)   0           ['activation_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 48, 48, 32)   4640        ['max_pooling2d[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 48, 48, 32)  128         ['conv2d_2[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 48, 48, 32)   0           ['batch_normalization_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 48, 48, 32)   9248        ['activation_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 48, 48, 32)  128         ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 48, 48, 32)   0           ['batch_normalization_3[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 24, 24, 32)  0           ['activation_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 24, 24, 48)   13872       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 24, 24, 48)  192         ['conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 24, 24, 48)   0           ['batch_normalization_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 24, 24, 48)   20784       ['activation_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 24, 24, 48)  192         ['conv2d_5[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 24, 24, 48)   0           ['batch_normalization_5[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 12, 12, 48)  0           ['activation_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 12, 12, 64)   27712       ['max_pooling2d_2[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 12, 12, 64)  256         ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 12, 12, 64)   0           ['batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 12, 12, 64)   36928       ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 12, 12, 64)  256         ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 12, 12, 64)   0           ['batch_normalization_7[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 6, 6, 64)    0           ['activation_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 6, 6, 64)     36928       ['max_pooling2d_3[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 6, 6, 64)    256         ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 6, 6, 64)     0           ['batch_normalization_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 6, 6, 64)     36928       ['activation_8[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 6, 6, 64)    256         ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 6, 6, 64)     0           ['batch_normalization_9[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 12, 12, 64)   0           ['activation_9[0][0]']
#
#  concatenate (Concatenate)      (None, 12, 12, 128)  0           ['up_sampling2d[0][0]',
#                                                                   'activation_7[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 12, 12, 64)   73792       ['concatenate[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 12, 12, 64)  256         ['conv2d_10[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 12, 12, 64)   0           ['batch_normalization_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 12, 12, 64)   36928       ['activation_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 12, 12, 64)  256         ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 12, 12, 64)   0           ['batch_normalization_11[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 24, 24, 64)  0           ['activation_11[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 24, 24, 112)  0           ['up_sampling2d_1[0][0]',
#                                                                   'activation_5[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 24, 24, 48)   48432       ['concatenate_1[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 24, 24, 48)  192         ['conv2d_12[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 24, 24, 48)   0           ['batch_normalization_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 24, 24, 48)   20784       ['activation_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 24, 24, 48)  192         ['conv2d_13[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 24, 24, 48)   0           ['batch_normalization_13[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 48, 48, 48)  0           ['activation_13[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 48, 48, 80)   0           ['up_sampling2d_2[0][0]',
#                                                                   'activation_3[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 48, 48, 32)   23072       ['concatenate_2[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 48, 48, 32)  128         ['conv2d_14[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 48, 48, 32)   0           ['batch_normalization_14[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 48, 48, 32)   9248        ['activation_14[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 48, 48, 32)  128         ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 48, 48, 32)   0           ['batch_normalization_15[0][0]']
#
#  up_sampling2d_3 (UpSampling2D)  (None, 96, 96, 32)  0           ['activation_15[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 96, 96, 48)   0           ['up_sampling2d_3[0][0]',
#                                                                   'activation_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 96, 96, 16)   6928        ['concatenate_3[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 96, 96, 16)  64          ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_16 (Activation)     (None, 96, 96, 16)   0           ['batch_normalization_16[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 96, 96, 16)   2320        ['activation_16[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 96, 96, 16)  64          ['conv2d_17[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 96, 96, 16)   0           ['batch_normalization_17[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 96, 96, 1)    17          ['activation_17[0][0]']
#
#  activation_18 (Activation)     (None, 96, 96, 1)    0           ['conv2d_18[0][0]']
#
# ==================================================================================================
# Total params: 414,401
# Trainable params: 412,865
# Non-trainable params: 1,536
# __________________________________________________________________________________________________

# %%
model.output.shape
# Out:
# TensorShape([None, 96, 96, 1])

# %%
#from data import load_data, tf_dataset#

# %%
from data import load_data #fish_08

# %%
if __name__ == "__main__":                                
     ## Dataset
     path = "/content/drive/MyDrive/Mtech_project/dataset/F4k_08"
     (train_x, train_y), (valid_x, valid_y), (test_x, test_y) = load_data(path)

# %%
len(train_x)
# Out:
# 176

# %%
from keras.preprocessing import image
import numpy as np
import cv2
from tensorflow.keras import backend as K
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
def read_and_preprocess_img_naz(img):
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    #x = preprocess_input(x)
    return x

# %%
def sigmoid(x, a, b, c):
    return c / (1 + np.exp(-a * (x-b)))
def superimpose1(original_img_path, cam, emphasize=False):
    
    img_bgr = cv2.imread(original_img_path)

    heatmap = cv2.resize(cam, (img_bgr.shape[1], img_bgr.shape[0]))
    if emphasize:
        heatmap = sigmoid(heatmap, 50, 0.5, 1)
    heatmap = np.uint8(255 * heatmap)
    heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)
    
    hif = .5
    superimposed_img = heatmap * hif + img_bgr
    superimposed_img = np.minimum(superimposed_img, 255.0).astype(np.uint8)  # scale 0 to 255  
    superimposed_img_rgb = cv2.cvtColor(superimposed_img, cv2.COLOR_BGR2RGB)
    
    return superimposed_img_rgb

# %%
for i in test_x:
  print(i)
# Out:
# /content/drive/MyDrive/Mtech_project/dataset/F4k_08/images/fish_000026930001_02782.png
# /content/drive/MyDrive/Mtech_project/dataset/F4k_08/images/fish_000026380001_02576.png
# /content/drive/MyDrive/Mtech_project/dataset/F4k_08/images/fish_000037699596_04304.png
# /content/drive/MyDrive/Mtech_project/dataset/F4k_08/images/fish_000026930001_02784.png
# /content/drive/MyDrive/Mtech_project/dataset/F4k_08/images/fish_003772196012_13071.png
# /content/drive/MyDrive/Mtech_project/dataset/F4k_08/images/fish_000026920001_02770.png
# /content/drive/MyDrive/Mtech_project/dataset/F4k_08/images/fish_000006019596_03826.png
# /content/drive/MyDrive/Mtech_project/dataset/F4k_08/images/fish_000027230001_02858.png
# /content/drive/MyDrive/Mtech_project/dataset/F4k_08/images/fish_003865466237_25528.png
# /content/drive/MyDrive/Mtech_project/dataset/F4k_08/images/fish_003460000108_03276.png
# /content/drive/MyDrive/Mtech_project/dataset/F4k_08/images/fish_003888846299_26670.png
# /content/drive/MyDrive/Mtech_project/dataset/F4k_08/images/fish_000026920001_02771.png
# /content/drive/MyDrive/Mtech_project/dataset/F4k_08/images/fish_003405435240_22895.png
# /content/drive/MyDrive/Mtech_project/dataset/F4k_08/images/fish_000026920001_02772.png
# /content/drive/MyDrive/Mtech_project/dataset/F4k_08/images/fish_000016839596_03985.png
# /content/drive/MyDrive/Mtech_project/dataset/F4k_08/images/fish_000033940001_03184.png
# /content/drive/MyDrive/Mtech_project/dataset/F4k_08/images/fish_000026610001_02660.png
# /content/drive/MyDrive/Mtech_project/dataset/F4k_08/images/fish_000027230001_02855.png
# /content/drive/MyDrive/Mtech_project/dataset/F4k_08/images/fish_003888196299_09810.png
# /content/drive/MyDrive/Mtech_project/dataset/F4k_08/images/fish_003460000108_03277.png
# /content/drive/MyDrive/Mtech_project/dataset/F4k_08/images/fish_000040059596_04367.png

# %%
model.output[:,0].shape
# Out:
# TensorShape([None, 96, 1])

# %%
path="/content/drive/MyDrive/Mtech_project/dataset/F4k_08/images/fish_000006019596_03828.png"
img = image.load_img(path, target_size=(96, 96), color_mode="rgb") #adjust according to model.summary input layer
"""x = read_and_preprocess_img_naz(img)

#plt.imshow(x.squeeze)
last_conv_layer = model.get_layer('up_sampling2d_3')
grad_cam=GradCam1(model,x,'up_sampling2d_3')
#print(grad)
  
print("grads_shape = ", grad_cam.shape)
"""

plt.imshow(img)
""""grad_cam_superimposed = superimpose1(path, grad_cam)
plt.imshow(grad_cam_superimposed)"""
# Out:
# '"grad_cam_superimposed = superimpose1(path, grad_cam)\nplt.imshow(grad_cam_superimposed)'

# %%
path="/content/drive/MyDrive/Mtech_project/dataset/fish_01/images/fish_000023460001_02244.png"
img = image.load_img(path, target_size=(96, 96), color_mode="rgb") #adjust according to model.summary input layer
x = read_and_preprocess_img_naz(img)

#plt.imshow(x.squeeze)
last_conv_layer = model.get_layer('up_sampling2d_3')
grad_cam_plus=GradCamPlusPlus(model,x,'up_sampling2d_3')
  #print(grad)
  
print("grads_shape = ", grad_cam_plus.shape)


#plt.imshow(img)
grad_cam_plus_superimposed = superimpose1(path, grad_cam_plus)
plt.imshow(grad_cam_plus_superimposed)
# Out:
# grads_shape =  (96, 96)

# %%
plt.imshow(grad_cam_plus)

# %%
img_path="/content/drive/MyDrive/Mtech_project/dataset/F4k_08/fish_08/fish_000026930001_02782.png"
img = image.load_img(img_path, target_size=(96, 96), color_mode="rgb") #adjust according to model.summary input layer
img_array = read_and_preprocess_img_naz(img)

# %%
y_c =  model.output[:, 0]
y_c
# Out:
# <tf.Tensor 'strided_slice_7:0' shape=(None, 96, 1) dtype=float32>

# %%
conv_output = model.get_layer("up_sampling2d_1").output
conv_output
# Out:
# <tf.Tensor 'up_sampling2d_1/resize/ResizeNearestNeighbor:0' shape=(None, 24, 24, 64) dtype=float32>

# %%
grads = tf.gradients(y_c, conv_output)[0]
grads.shape
# Out:
# TensorShape([None, 24, 24, 64])

# %%
gradient_function = K.function([model.input], [conv_output, grads])
output, grads_val = gradient_function([img_array])
output.shape
# Out:
# (1, 24, 24, 64)

# %%
grads_val.shape
# Out:
# (1, 24, 24, 64)

# %%
output[0, :].shape
# Out:
# (24, 24, 64)

# %%
grads_val[0, :].shape
# Out:
# (24, 24, 64)

# %%
 weights = np.mean(grads_val, axis=(0, 1))
 weights.shape
# Out:
# (24, 64)

# %%
def GradCam2(model, img_array, layer_name):
    #cls = np.argmax(model.predict(img_array))
    
    """GradCAM method for visualizing input saliency."""
    y_c =  model.output[:, 0] #index = 0 since there is only 1 output from the network
    conv_output = model.get_layer(layer_name).output
    grads = tf.gradients(y_c, conv_output)[0]
    # grads = normalize(grads)

    gradient_function = K.function([model.input], [conv_output, grads])
    output, grads_val = gradient_function([img_array])
    output, grads_val = output[0, :], grads_val[0, :, :, :]
    weights = np.mean(grads_val, axis=(0, 1))

    cam = np.dot(output, weights)
    cam = np.maximum(cam, 0)  # Passing through ReLU
    if (np.max(cam)) == 0:
      return cam
      
    else:  
      cam /= np.max(cam)  # scale 0 to 1.0  

    return cam

# %%
model.summary()

# %%
layer_name = "conv2d_13"
#img_path="/content/drive/MyDrive/Mtech_project/dataset/F4k_08/fish_08/fish_000026380001_02576.png"
#img_path="/content/drive/MyDrive/Mtech_project/dataset/F4k_08/images/fish_000006019596_03828.png"
img_path ="/content/fish_000004380001_00174.png"
img = image.load_img(img_path, target_size=(96, 96), color_mode="rgb") #adjust according to model.summary input layer
img_array = read_and_preprocess_img_naz(img)

grad_cam=GradCam1(model,img_array,layer_name)
grad_cam_superimposed = superimpose(img_path, grad_cam)
grad_cam_emphasized = superimpose(img_path, grad_cam, emphasize=True)

'''grad_cam_plus_plus=GradCamPlusPlus(model,img_array,layer_name)
grad_cam_plus_plus_superimposed = superimpose1(img_path, grad_cam_plus_plus)
grad_cam_plus_plus_emphasized = superimpose(img_path, grad_cam_plus_plus, emphasize=True)'''
# Out:
# 0.026947232
# 'grad_cam_plus_plus=GradCamPlusPlus(model,img_array,layer_name)\ngrad_cam_plus_plus_superimposed = superimpose1(img_path, grad_cam_plus_plus)\ngrad_cam_plus_plus_emphasized = superimpose(img_path, grad_cam_plus_plus, emphasize=True)'

# %% [markdown]
# # max_pooling2d_2 concatenate_1   up_sampling2d_1
#  max_pooling2d_3 concatenate   up_sampling2d

# %%
img = image.load_img(img_path)
fig, ax = plt.subplots(nrows=2,ncols=3, figsize=(18, 11))
ax[0,0].imshow(img)
ax[0,0].set_title("input image")
ax[0,1].imshow(grad_cam)
ax[0,1].set_title("Grad-CAM")
#ax[0,2].imshow(grad_cam_plus_plus)
ax[0,2].set_title("Grad-CAM++")
#ax[0,4].imshow(faster_score_cam)
#ax[0,4].set_title("Faster-Score-CAM")
ax[1,0].imshow(grad_cam_emphasized)
ax[1,0].set_title("grad_cam_emphasized")
ax[1,1].imshow(grad_cam_superimposed)
ax[1,1].set_title("grad-cam-superimposed")
#ax[1,2].imshow(grad_cam_plus_plus_superimposed)
ax[1,2].set_title("Grad-CAM++ - superimposed")
#ax[0,4].imshow(faster_score_cam_superimposed)
#ax[0,4].set_title("Faster-Score-CAM")
for i in range(2):
    for j in range(3):
        ax[i,j].axis('off')
#plt.savefig('/content/drive/MyDrive/Mtech_project/Nazrin_F4K_segmentation_Model1/Unet_segmentation/results/feb8_3_gradcam.pdf',dpi=600,bbox_inches='tight')
#plt.savefig('/content/drive/MyDrive/Mtech_project/Nazrin_F4K_segmentation_Model1/Unet_segmentation/results/feb8_3_gradcam.tif',dpi=600,bbox_inches='tight')
plt.show()

# %%
layer_name = "up_sampling2d_2"
'''img_path="/content/drive/MyDrive/Mtech_project/dataset/F4k_08/fish_08/fish_000026380001_02576.png"
img = image.load_img(img_path, target_size=(96,96), color_mode="rgb") #adjust according to model.summary input layer
img_array = read_and_preprocess_img_naz(img)'''

grad_cam=GradCam1(model,img_array,layer_name)
grad_cam_superimposed = superimpose1(img_path, grad_cam)
grad_cam_emphasized = superimpose(img_path, grad_cam, emphasize=True)

img = image.load_img(img_path, target_size=(48,48), color_mode="rgb") #adjust according to model.summary input layer
img_array = read_and_preprocess_img_naz(img)

'''grad_cam_plus_plus=GradCamPlusPlus(model,img_array,layer_name)
grad_cam_plus_plus_superimposed = superimpose1(img_path, grad_cam_plus_plus)
grad_cam_plus_plus_emphasized = superimpose(img_path, grad_cam_plus_plus, emphasize=True)'''

img = image.load_img(img_path)
fig, ax = plt.subplots(nrows=2,ncols=3, figsize=(18, 11))
ax[0,0].imshow(img)
ax[0,0].set_title("input image")
ax[0,1].imshow(grad_cam)
ax[0,1].set_title("Grad-CAM")
#ax[0,2].imshow(grad_cam_plus_plus)
ax[0,2].set_title("Grad-CAM++")
#ax[0,4].imshow(faster_score_cam)
#ax[0,4].set_title("Faster-Score-CAM")
ax[1,0].imshow(img)
ax[1,0].set_title("input image")
ax[1,1].imshow(grad_cam_superimposed)
ax[1,1].set_title("Grad-CAM-superimposed")
#ax[1,2].imshow(grad_cam_plus_plus_superimposed)
ax[1,2].set_title("Grad-CAM++ - superimposed")
#ax[0,4].imshow(faster_score_cam_superimposed)
#ax[0,4].set_title("Faster-Score-CAM")
for i in range(2):
    for j in range(3):
        ax[i,j].axis('off')
plt.savefig('/content/drive/MyDrive/Mtech_project/Nazrin_F4K_segmentation_Model1/Unet_segmentation/results/2_cams_jan31/d2_4.pdf',dpi=600,bbox_inches='tight')
plt.show()
# Out:
# 0.00071112247

# %%
layer_name = "up_sampling2d_1"
'''img_path="/content/drive/MyDrive/Mtech_project/dataset/F4k_08/fish_08/fish_000026380001_02576.png"
img = image.load_img(img_path, target_size=(96, 96), color_mode="rgb") #adjust according to model.summary input layer
img_array = read_and_preprocess_img_naz(img)'''

grad_cam=GradCam1(model,img_array,layer_name)
grad_cam_superimposed = superimpose1(img_path, grad_cam)
grad_cam_emphasized = superimpose(img_path, grad_cam, emphasize=True)

'''grad_cam_plus_plus=GradCamPlusPlus(model,img_array,layer_name)
grad_cam_plus_plus_superimposed = superimpose1(img_path, grad_cam_plus_plus)
grad_cam_plus_plus_emphasized = superimpose(img_path, grad_cam_plus_plus, emphasize=True)
'''
img = image.load_img(img_path)
fig, ax = plt.subplots(nrows=2,ncols=3, figsize=(18, 11))
ax[0,0].imshow(img)
ax[0,0].set_title("input image")
ax[0,1].imshow(grad_cam)
ax[0,1].set_title("Grad-CAM")
#ax[0,2].imshow(grad_cam_plus_plus)
ax[0,2].set_title("Grad-CAM++")
#ax[0,4].imshow(faster_score_cam)
#ax[0,4].set_title("Faster-Score-CAM")
ax[1,0].imshow(img)
ax[1,0].set_title("input image")
ax[1,1].imshow(grad_cam_superimposed)
ax[1,1].set_title("Grad-CAM-superimposed")
#ax[1,2].imshow(grad_cam_plus_plus_superimposed)
ax[1,2].set_title("Grad-CAM++ - superimposed")
#ax[0,4].imshow(faster_score_cam_superimposed)
#ax[0,4].set_title("Faster-Score-CAM")
for i in range(2):
    for j in range(3):
        ax[i,j].axis('off')
plt.savefig('/content/drive/MyDrive/Mtech_project/Nazrin_F4K_segmentation_Model1/Unet_segmentation/results/2_cams_jan31/d1_4.pdf',dpi=600,bbox_inches='tight')
plt.show()

# %%
layer_name = "activation_3"
img_path="/content/drive/MyDrive/Mtech_project/dataset/F4k_08/fish_08/fish_000007200001_00910.png"
img = image.load_img(img_path, target_size=(96, 96), color_mode="rgb") #adjust according to model.summary input layer
img_array = read_and_preprocess_img_naz(img)

grad_cam=GradCam1(model,img_array,layer_name)
grad_cam_superimposed = superimpose1(img_path, grad_cam)
grad_cam_emphasized = superimpose(img_path, grad_cam, emphasize=True)

'''grad_cam_plus_plus=GradCamPlusPlus(model,img_array,layer_name)
grad_cam_plus_plus_superimposed = superimpose1(img_path, grad_cam_plus_plus)
grad_cam_plus_plus_emphasized = superimpose(img_path, grad_cam_plus_plus, emphasize=True)'''

img = image.load_img(img_path)
fig, ax = plt.subplots(nrows=2,ncols=3, figsize=(18, 11))
ax[0,0].imshow(img)
ax[0,0].set_title("input image")
ax[0,1].imshow(grad_cam)
ax[0,1].set_title("Grad-CAM")
#ax[0,2].imshow(grad_cam_plus_plus)
ax[0,2].set_title("Grad-CAM++")
#ax[0,4].imshow(faster_score_cam)
#ax[0,4].set_title("Faster-Score-CAM")
ax[1,0].imshow(img)
ax[1,0].set_title("input image")
ax[1,1].imshow(grad_cam_superimposed)
ax[1,1].set_title("Grad-CAM-superimposed")
#ax[1,2].imshow(grad_cam_plus_plus_superimposed)
ax[1,2].set_title("Grad-CAM++ - superimposed")
#ax[0,4].imshow(faster_score_cam_superimposed)
#ax[0,4].set_title("Faster-Score-CAM")
for i in range(2):
    for j in range(3):
        ax[i,j].axis('off')
plt.savefig('/content/drive/MyDrive/Mtech_project/Nazrin_F4K_segmentation_Model1/Unet_segmentation/results/2_cams_jan31/d_2.pdf',dpi=600,bbox_inches='tight')
plt.show()
